# %%
import nltk

nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# True

# %%
from nltk.wsd import lesk
from nltk.tokenize import word_tokenize
from nltk.corpus import wordnet as wn

# %%
sentence = "I walked into the Bombay stock Exchange building"
word = "stock"

tokens = word_tokenize(sentence)

sense = lesk(tokens, word)

print("Sentence:", sentence)
print("Ambiguous Word:", word)
print("Predicted Sense:", sense)
print("Definition:", sense.definition())
# Out:
# Sentence: I walked into the Bombay stock Exchange building
# Ambiguous Word: stock
# Predicted Sense: Synset('stock_certificate.n.01')
# Definition: a certificate documenting the shareholder's ownership in the corporation
